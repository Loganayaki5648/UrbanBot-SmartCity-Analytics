# %%
# !pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from ultralytics import YOLO

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/MyDrive"
# Out:
#  CAN_39373990_certificate.pdf	  IMG-20260507-WA0228.jpg
# 'Colab Notebooks'		  inbound8711889943024650579.pdf
# 'Copy of titanic_train (1).csv'  'LOGANAYAKI C resume (1).pdf'
# 'Copy of titanic_train.csv'	 'LOGANAYAKI C resume.pdf'
# 'Getting started.pdf'		 'Pothole Colab Notebooks'
#  IMG-20240606-WA0087.jpg	  Pothole_dataset
#  IMG-20260507-WA0226.jpg	 'Screenshot 2025-10-07 164249.png'
#  IMG-20260507-WA0227.jpg	 'Streetlights Detection.v1i.yolov8'

# %%
# !ls "/content/drive/MyDrive/Streetlights Detection.v1i.yolov8"
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
model = YOLO("yolov8n.pt")

model.train(
    data="/content/drive/MyDrive/Streetlights Detection.v1i.yolov8/data.yaml",
    epochs=10,
    imgsz=224,
    batch=8,
    device=0
)
# Out:
# Ultralytics 8.4.90 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !ls runs/detect/train/weights

# %%
# !ls runs/detect/train-3/weights
# Out:
# best.pt  last.pt

# %%
# !cp runs/detect/train-3/weights/best.pt "/content/drive/MyDrive/streetlight_best.pt"

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train-3/weights/best.pt")

# %%
results = model.predict(
    source="/content/drive/MyDrive/Streetlights Detection.v1i.yolov8/test/images",
    save=True,
    conf=0.5
)

print("Prediction Completed")
# Out:
# image 1/12 /content/drive/MyDrive/Streetlights Detection.v1i.yolov8/test/images/Concrete_streetlights_with_Thorn_Alpha_8_lanterns-_Poole_Dorset_-_Coppermine_-_6328_jpeg.rf.47e3e139393503eb2731476cf29df266.jpg: 224x224 (no detections), 9.6ms
# image 2/12 /content/drive/MyDrive/Streetlights Detection.v1i.yolov8/test/images/LED_street_light_-_Getty_kievith_jpeg.rf.e7b7b0c69edac7d42373fad51c715ec5.jpg: 224x224 (no detections), 9.7ms
# image 3/12 /content/drive/MyDrive/Streetlights Detection.v1i.yolov8/test/images/Screen-Shot-2022-03-23-at-10-23-56-AM_png.rf.d00c5f26d6f166f0afa6e12c45f7d848.jpg: 224x224 (no detections), 6.3ms
# image 4/12 /content/drive/MyDrive/Streetlights Detection.v1i.yolov8/test/images/Screen-Shot-2022-03-23-at-10-24-21-AM_png.rf.21d3423ce1c94e99ef0487ff3c199dc6.jpg: 224x224 (no detections), 6.5ms
# ...

# %%
from IPython.display import Image, display
import glob

img = glob.glob("runs/detect/predict/*")[0]
display(Image(filename=img))

# %%
# !ls "/content/drive/MyDrive/Streetlights Detection.v1i.yolov8/test/images"
# Out:
# Concrete_streetlights_with_Thorn_Alpha_8_lanterns-_Poole_Dorset_-_Coppermine_-_6328_jpeg.rf.47e3e139393503eb2731476cf29df266.jpg
# LED_street_light_-_Getty_kievith_jpeg.rf.e7b7b0c69edac7d42373fad51c715ec5.jpg
# Screen-Shot-2022-03-23-at-10-23-56-AM_png.rf.d00c5f26d6f166f0afa6e12c45f7d848.jpg
# Screen-Shot-2022-03-23-at-10-24-21-AM_png.rf.21d3423ce1c94e99ef0487ff3c199dc6.jpg
# Screen-Shot-2022-03-23-at-10-25-05-AM_png.rf.74ca4656083ed452f71cb18ffefd0411.jpg
# Screen-Shot-2022-04-06-at-11-31-54-AM_png.rf.d6258e85d78a481dec20352c21772b28.jpg
# Screen-Shot-2022-04-06-at-11-34-27-AM_png.rf.cec7283b5e2154e41740b8d01db0b112.jpg
# Screen-Shot-2022-04-06-at-11-53-46-AM_png.rf.e0f72b46cbc6eac460be9cec15bf8265.jpg
# Screen-Shot-2022-04-06-at-11-54-00-AM_png.rf.505f88ab6619c0a980f6fc9b11297481.jpg
# Screen-Shot-2022-04-06-at-11-54-22-AM_png.rf.7b59ccc6adaade898735cb383d873bc5.jpg
# Screen-Shot-2022-04-06-at-12-00-53-PM_png.rf.2bdc33ff0c51bb171a409229cc219858.jpg
# ...

# %%
from ultralytics import YOLO


model = YOLO("runs/detect/train-3/weights/best.pt")


results = model.predict(
    source="/content/drive/MyDrive/Streetlights Detection.v1i.yolov8/test/images/LED_street_light_-_Getty_kievith_jpeg.rf.e7b7b0c69edac7d42373fad51c715ec5.jpg",
    save=True,
    conf=0.5
)

print("Prediction Completed")
# Out:
# image 1/1 /content/drive/MyDrive/Streetlights Detection.v1i.yolov8/test/images/LED_street_light_-_Getty_kievith_jpeg.rf.e7b7b0c69edac7d42373fad51c715ec5.jpg: 224x224 (no detections), 14.4ms
# Speed: 1.2ms preprocess, 14.4ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /content/runs/detect/predict-2
# Prediction Completed

# %%
from IPython.display import Image, display
import glob

img = glob.glob("runs/detect/predict*/*jpg")[0]
display(Image(filename=img))

# %%
# !cp runs/detect/train-3/weights/best.pt "/content/drive/MyDrive/streetlight_best.pt"

# %%
# !ls "/content/drive/MyDrive"
# Out:
#  CAN_39373990_certificate.pdf	  inbound8711889943024650579.pdf
# 'Colab Notebooks'		 'LOGANAYAKI C resume (1).pdf'
# 'Copy of titanic_train (1).csv'  'LOGANAYAKI C resume.pdf'
# 'Copy of titanic_train.csv'	 'Pothole Colab Notebooks'
# 'Getting started.pdf'		  Pothole_dataset
#  IMG-20240606-WA0087.jpg	 'Screenshot 2025-10-07 164249.png'
#  IMG-20260507-WA0226.jpg	  streetlight_best.pt
#  IMG-20260507-WA0227.jpg	 'Streetlights Detection.v1i.yolov8'
#  IMG-20260507-WA0228.jpg

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/streetlight_best.pt")

print("Streetlight Model Loaded Successfully")
# Out:
# Streetlight Model Loaded Successfully
